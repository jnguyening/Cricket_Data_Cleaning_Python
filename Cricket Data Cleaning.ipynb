# %%
#import pandas as pd

# %%
import pandas as pd

# %%
#import csv

# %%
df = pd.read_csv('CricketTestMatchData.csv')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7  626+   6
# ...

# %%
#rename multiple coulmns in a list

# %%
df = df.rename(columns = {'Mat':'Matches', 'NO':'Not_Outs', 'HS':'Highest_Inns_score', 'BF':'Balls_Faced', 'SR':'Batting_Strike_Rate'})

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1  PHKD Mendis (SL)  2022-2025       12    21         2  1184
# 2    AC Voges (AUS)  2015-2016       20    31         7  1485
# 3   RG Pollock (SA)  1963-1970       23    41         4  2256
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
#
#   Highest_Inns_score    Ave Balls_Faced Batting_Strike_Rate  100  50  0    4s  \
# 0                334  99.94       9800+                58.6   29  13  7  626+
# 1               182*  62.31        1839               64.38    5   4  -   123
# 2               269*  61.87        2667               55.68    5   4  2   186
# 3                274  60.97       1707+               54.48    7  11  1  246+
# 4               270*  60.83        416+                  56   10   5  2  104+
#
#    6s
# 0   6
# 1  23
# 2   5
# 3  11
# 4   1

# %%
#check null values

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 9    ED Weekes (WI)  1948-1958       48    81         5  4455
# 18  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_Inns_score    Ave Balls_Faced Batting_Strike_Rate  100  50  0  \
# 9                 207  58.61         NaN                 NaN   15  19  6
# 18                220  56.68         NaN                 NaN   15  14  1
#
#       4s  6s
# 9   258+   2
# 18  107+  11

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)

# %%
df[df['Player']=='CL Walcott (WI)']
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 18  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_Inns_score    Ave Balls_Faced Batting_Strike_Rate  100  50  0  \
# 18                220  56.68           0                   0   15  14  1
#
#       4s  6s
# 18  107+  11

# %%
#drop duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                  Player       Span  Matches  Inns  Not_Outs  Runs  \
# 5       GA Headley (WI)  1930-1954       22    40         4  2190
# 13       GS Sobers (WI)  1954-1974       93   160        21  8032
# 16       JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 59  TT Samaraweera (SL)  2001-2013       81   132        20  5462
#
#    Highest_Inns_score    Ave Balls_Faced Batting_Strike_Rate  100  50   0  \
# 5                270*  60.83        416+                  56   10   5   2
# 13               365*  57.78       4063+               53.58   26  30  12
# 16                211  56.94       5363+               46.22   15  28   4
# 59                231  48.76       11641               46.92   14  30  11
#
#       4s   6s
# 5   104+    1
# 13  593+  32+
# 16  276+    8
# 59   633    7

# %%
df[df['Player'].isin(['GA Headley (WI)','GS Sobers (WI)','JB Hobbs (ENG)','TT Samaraweera (SL)'])]
# Out:
#                  Player       Span  Matches  Inns  Not_Outs  Runs  \
# 4       GA Headley (WI)  1930-1954       22    40         4  2190
# 5       GA Headley (WI)  1930-1954       22    40         4  2190
# 12       GS Sobers (WI)  1954-1974       93   160        21  8032
# 13       GS Sobers (WI)  1954-1974       93   160        21  8032
# 15       JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 16       JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 58  TT Samaraweera (SL)  2001-2013       81   132        20  5462
# 59  TT Samaraweera (SL)  2001-2013       81   132        20  5462
#
#    Highest_Inns_score    Ave Balls_Faced Batting_Strike_Rate  100  50   0  \
# 4                270*  60.83        416+                  56   10   5   2
# 5                270*  60.83        416+                  56   10   5   2
# 12               365*  57.78       4063+               53.58   26  30  12
# 13               365*  57.78       4063+               53.58   26  30  12
# ...

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['GA Headley (WI)','GS Sobers (WI)','JB Hobbs (ENG)','TT Samaraweera (SL)'])]
# Out:
#                  Player       Span  Matches  Inns  Not_Outs  Runs  \
# 4       GA Headley (WI)  1930-1954       22    40         4  2190
# 12       GS Sobers (WI)  1954-1974       93   160        21  8032
# 15       JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 58  TT Samaraweera (SL)  2001-2013       81   132        20  5462
#
#    Highest_Inns_score    Ave Balls_Faced Batting_Strike_Rate  100  50   0  \
# 4                270*  60.83        416+                  56   10   5   2
# 12               365*  57.78       4063+               53.58   26  30  12
# 15                211  56.94       5363+               46.22   15  28   4
# 58                231  48.76       11641               46.92   14  30  11
#
#       4s   6s
# 4   104+    1
# 12  593+  32+
# 15  276+    8
# 58   633    7

# %%
#split up span into start and end date

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2025]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat = '-').str[1]
# Out:
# 0     1948
# 1     2025
# 2     2016
# 3     1970
# 4     1954
#       ...
# 61    1981
# 62    2014
# 63    1934
# 64    1938
# 65    1934
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    PHKD Mendis (SL)  2022-2025       12    21         2  1184
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 61   KD Walters (AUS)  1965-1981       74   125        14  5357
# 62  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 63  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 64    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 65   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_score    Ave Balls_Faced Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.6   29  13   7
# ...

# %%
#drop span columns

# %%
df = df.drop(['Span'], axis = 1)

# %%
df.head()
# Out:
#              Player  Matches  Inns  Not_Outs  Runs Highest_Inns_score    Ave  \
# 0  DG Bradman (AUS)       52    80        10  6996                334  99.94
# 1  PHKD Mendis (SL)       12    21         2  1184               182*  62.31
# 2    AC Voges (AUS)       20    31         7  1485               269*  61.87
# 3   RG Pollock (SA)       23    41         4  2256                274  60.97
# 4   GA Headley (WI)       22    40         4  2190               270*  60.83
#
#   Balls_Faced Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year Final_Year
# 0       9800+                58.6   29  13  7  626+   6        1928       1948
# 1        1839               64.38    5   4  -   123  23        2022       2025
# 2        2667               55.68    5   4  2   186   5        2015       2016
# 3       1707+               54.48    7  11  1  246+  11        1963       1970
# 4        416+                  56   10   5  2  104+   1        1930       1954

# %%
#split up the country from the player

# %%
df['Player'].str.split(pat = '(')
# Out:
# 0      [DG Bradman , AUS)]
# 1      [PHKD Mendis , SL)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 61     [KD Walters , AUS)]
# 62    [GC Smith , ICC/SA)]
# 63    [WH Ponsford , AUS)]
# 64      [SJ McCabe , AUS)]
# 65     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['Country'] = df['Country'].str.split(pat = ')').str[0]

# %%
df['Country']
# Out:
# 0        AUS
# 1         SL
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 61       AUS
# 62    ICC/SA
# 63       AUS
# 64       AUS
# 65       ENG
# Name: Country, Length: 62, dtype: object

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs Highest_Inns_score    Ave  \
# 0   DG Bradman        52    80        10  6996                334  99.94
# 1  PHKD Mendis        12    21         2  1184               182*  62.31
# 2     AC Voges        20    31         7  1485               269*  61.87
# 3   RG Pollock        23    41         4  2256                274  60.97
# 4   GA Headley        22    40         4  2190               270*  60.83
#
#   Balls_Faced Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.6   29  13  7  626+   6        1928
# 1        1839               64.38    5   4  -   123  23        2022
# 2        2667               55.68    5   4  2   186   5        2015
# 3       1707+               54.48    7  11  1  246+  11        1963
# 4        416+                  56   10   5  2  104+   1        1930
#
#   Final_Year Country
# 0       1948     AUS
# 1       2025      SL
# 2       2016     AUS
# 3       1970      SA
# ...

# %%
#change data types

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate     object
# 100                      int64
# 50                       int64
# 0                       object
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Highest_Inns_score'].str.split(pat = '*').str[0]
# Out:
# 0     334
# 1     182
# 2     269
# 3     274
# 4     270
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_Inns_score, Length: 62, dtype: object

# %%
df['Highest_Inns_score'] = df['Highest_Inns_score'].str.split(pat = '*').str[0]

# %%
df['Highest_Inns_score']
# Out:
# 0     334
# 1     182
# 2     269
# 3     274
# 4     270
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_Inns_score, Length: 62, dtype: object

# %%
df['Highest_Inns_score'] = df['Highest_Inns_score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_score       int32
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate     object
# 100                      int64
# 50                       int64
# 0                       object
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df = df.astype({'Rookie_Year':'int', 'Final_Year':'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_score       int32
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate     object
# 100                      int64
# 50                       int64
# 0                       object
# 4s                      object
# 6s                      object
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_score    Ave  \
# 0   DG Bradman        52    80        10  6996                 334  99.94
# 1  PHKD Mendis        12    21         2  1184                 182  62.31
# 2     AC Voges        20    31         7  1485                 269  61.87
# 3   RG Pollock        23    41         4  2256                 274  60.97
# 4   GA Headley        22    40         4  2190                 270  60.83
#
#   Balls_Faced Batting_Strike_Rate  100  50  0    4s  6s  Rookie_Year  \
# 0       9800+                58.6   29  13  7  626+   6         1928
# 1        1839               64.38    5   4  -   123  23         2022
# 2        2667               55.68    5   4  2   186   5         2015
# 3       1707+               54.48    7  11  1  246+  11         1963
# 4        416+                  56   10   5  2  104+   1         1930
#
#    Final_Year Country
# 0        1948     AUS
# 1        2025      SL
# 2        2016     AUS
# ...

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#          Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_score    Ave  \
# 9    ED Weekes        48    81         5  4455                 207  58.61
# 18  CL Walcott        44    74         7  3798                 220  56.68
#
#    Balls_Faced Batting_Strike_Rate  100  50  0    4s  6s  Rookie_Year  \
# 9          NaN                   0   15  19  6  258+   2         1948
# 18         NaN                   0   15  14  1  107+  11         1948
#
#     Final_Year Country
# 9         1958      WI
# 18        1960      WI

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_Outs, Runs, Highest_Inns_score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s, Rookie_Year, Final_Year, Country]
# Index: []

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_score  \
# 0         DG Bradman        52    80        10   6996                 334
# 1        PHKD Mendis        12    21         2   1184                 182
# 2           AC Voges        20    31         7   1485                 269
# 3         RG Pollock        23    41         4   2256                 274
# 4         GA Headley        22    40         4   2190                 270
# 6        H Sutcliffe        54    84         9   4555                 194
# 7          E Paynter        20    31         5   1540                 243
# 8      KF Barrington        82   131        15   6806                 256
# 9          ED Weekes        48    81         5   4455                 207
# 10          HC Brook        24    40         1   2281                 317
# 11        WR Hammond        85   140        16   7249                 336
# 12         GS Sobers        93   160        21   8032                 365
# ...

# %%
#remove FS Jackson Row

# %%
df = df.drop(57, axis = 0)

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_score  \
# 0         DG Bradman        52    80        10   6996                 334
# 1        PHKD Mendis        12    21         2   1184                 182
# 2           AC Voges        20    31         7   1485                 269
# 3         RG Pollock        23    41         4   2256                 274
# 4         GA Headley        22    40         4   2190                 270
# 6        H Sutcliffe        54    84         9   4555                 194
# 7          E Paynter        20    31         5   1540                 243
# 8      KF Barrington        82   131        15   6806                 256
# 9          ED Weekes        48    81         5   4455                 207
# 10          HC Brook        24    40         1   2281                 317
# 11        WR Hammond        85   140        16   7249                 336
# 12         GS Sobers        93   160        21   8032                 365
# ...

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_score       int32
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate     object
# 100                      int64
# 50                       int64
# 0                       object
# 4s                      object
# 6s                      object
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].astype('float')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_score       int32
# Ave                    float64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                       object
# 4s                      object
# 6s                      object
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['Career_Length'] = df['Final_Year'] - df['Rookie_Year']

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_score  \
# 0         DG Bradman        52    80        10   6996                 334
# 1        PHKD Mendis        12    21         2   1184                 182
# 2           AC Voges        20    31         7   1485                 269
# 3         RG Pollock        23    41         4   2256                 274
# 4         GA Headley        22    40         4   2190                 270
# 6        H Sutcliffe        54    84         9   4555                 194
# 7          E Paynter        20    31         5   1540                 243
# 8      KF Barrington        82   131        15   6806                 256
# 9          ED Weekes        48    81         5   4455                 207
# 10          HC Brook        24    40         1   2281                 317
# 11        WR Hammond        85   140        16   7249                 336
# 12         GS Sobers        93   160        21   8032                 365
# ...

# %%
#calculations

# %%
#cricketers in this df what is the average career length

# %%
df['Career_Length'].mean()
# Out:
# 12.98360655737705

# %%
#avg batting strike rate for cricketers who played over 10 years

# %%
df[df['Career_Length'] > 10]['Batting_Strike_Rate'].mean()
# Out:
# 48.93999999999999

# %%
#find the number of cricketers who played before 1960

# %%
df[df['Rookie_Year'] < 1960]['Player'].count()
# Out:
# 22

# %%
#max highest inns score by country

# %%
df.groupby('Country')['Highest_Inns_score'].max().to_frame('HighInnsCountry').reset_index().sort_values('HighInnsCountry', ascending = False)
# Out:
#     Country  HighInnsCountry
# 5    ICC/WI              400
# 0       AUS              380
# 10       SL              374
# 11       WI              365
# 1       ENG              364
# 3   ICC/PAK              329
# 2   ICC/IND              319
# 8       PAK              313
# 9        SA              278
# 4    ICC/SA              277
# 7        NZ              251
# 6       IND              248
# 12      ZIM              232

# %%
#hundreds, fifties, ducks (0) avg by country

# %%
df['0'].replace('-', '0').astype(int)
# Out:
# 0      7
# 1      0
# 2      2
# 3      1
# 4      2
# 6      2
# 7      3
# 8      5
# 9      6
# 10     2
# 11     4
# 12    12
# 14    11
# 15     4
# 17    11
# 18     1
# 19     5
# 20    16
# 21     2
# 22    11
# 23     1
# 24     3
# 25    12
# 26     3
# 27    14
# 28    17
# 29     3
# 30     6
# 31     8
# 32    11
# 33    19
# 34    17
# 35     1
# 36     5
# 37    12
# 38    15
# 39    12
# 40    22
# 41    13
# 42    14
# 43     8
# 44    11
# 45     2
# 46    10
# 47    10
# 48    15
# 49    15
# 50    11
# 51     3
# 52    16
# 53     2
# 54     9
# 55     2
# 56     3
# 58    11
# 60     7
# 61     4
# 62    11
# 63     1
# 64     4
# 65     2
# Name: 0, dtype: int32

# %%
df['0'] = df['0'].replace('-', '0').astype(float)

# %%
df.groupby('Country')[['100', '50', '0']].mean()
# Out:
#                100         50          0
# Country
# AUS      21.533333  28.933333   8.933333
# ENG      13.750000  22.666667   4.583333
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      23.250000  31.500000   8.000000
# NZ       33.000000  37.000000  11.000000
# PAK      17.800000  24.200000   8.000000
# SA        9.800000  20.200000   3.400000
# SL       22.750000  34.000000   9.250000
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
